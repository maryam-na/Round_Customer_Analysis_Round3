# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('merged_clean_ver2.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lesson 1

# %% [markdown]
# # Matplotlib
#
# - external links:
#    - https://realpython.com/python-matplotlib-guide/
#    - https://matplotlib.org/stable/users/resources/index.html
#
#  # Seaborn
#
#    - Seaborn is a  data visualization library based on matplotlib
#    - is more comfortable in handling Pandas data frames

# %% [markdown]
# # Descriptive Statistics
#
# #### Descriptive statistics summarizes or describes the characteristics of a data set.
# #### - Descriptive statistics consists of two basic categories of measures:
# ##### - measures of central tendency and measures of variability (or spread).

# %% [markdown]
# ## Probability distribution
#
# - a probability distribution is the mathematical function that gives the probabilities of occurrence of different possible outcomes for an experiment. It is a mathematical description of a random phenomenon in terms of its sample space and the probabilities of events
# ![image-3.png](attachment:image-3.png)
#
#
# ## Measures of central tendency
# - A measure of central tendency (also referred to as measures of centre or central location) is a summary measure that attempts to describe a whole set of data with a single value that represents the middle or centre of its distribution.
# - Mean: The mean is the sum of the value of each observation in a dataset divided by the number of observations. This is also known as the arithmetic average.
# - median:The median is the middle value in distribution when the values are arranged in ascending or descending order.
#
# - mode:The mode is the most commonly occurring value in a distribution.
# ## Measures of spread / dispersion -
# - SD : It is a measure of spread of data about the mean. SD is the square root of sum of squared deviation from the mean divided by the number of observations.
# - https://www.mathsisfun.com/data/standard-deviation.html
# ![image.png](attachment:image.png)
#
# - var
#
# ![image-2.png](attachment:image-2.png)
# - range: Range is the interval between the highest and the lowest score
# - quartile : 25% of data each
# - interquartile range :  describes the middle 50% of observations.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %%
data
# Out:
#           id state gender  median_home_val  median_household_income  ic2  ic3  \
# 0      44060    FL      M      1158.437751                      392  430  466
# 1      96093    IL      M       537.000000                      365  415  410
# 2      43333    FL      F       725.000000                      301  340  361
# 3      21885    NC      M      1158.437751                      401  407  399
# 4     190108    FL      F       995.000000                      252  280  316
# ...      ...   ...    ...              ...                      ...  ...  ...
# 3988   66762    MI      F       632.000000                      279  336  339
# 3989    6443    FL      M       595.000000                      252  263  262
# 3990  151175    CA      F      2707.000000                      507  504  538
# 3991  151504    CA      M      2666.000000                      535  609  612
# 3992   74303    MI      M       444.000000                      225  264  269
#
# ...

# %%
def clean(x):
    if x in ['M', 'MALE']:
        return 'Male'
    elif x.startswith('F'):
        return 'Female'
    else:
        return 'U'

# %%
data['gender'] = list(map(clean, data['gender']))

# %%
data['gender'].unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)

# %%
# ![image-3.png](attachment:image-3.png)

# %%
data.describe()
# data.describe(include=[np.number])
# Out:
#                   id  median_home_val  median_household_income          ic2  \
# count    3993.000000      3993.000000              3993.000000  3993.000000
# mean    98929.308039      1158.437751               351.622840   400.713248
# std     58179.839090      1033.485773               168.488445   180.568500
# min        12.000000         0.000000                 0.000000     0.000000
# 25%     46153.000000       548.000000               239.000000   284.000000
# 50%    101432.000000       803.000000               318.000000   366.000000
# 75%    151653.000000      1349.000000               425.000000   478.000000
# max    191779.000000      5982.000000              1500.000000  1500.000000
#
#                ic3          ic4            ic5      avggift     target_d
# count  3993.000000  3993.000000    3993.000000  3993.000000  3993.000000
# mean    399.876283   444.732031   16456.413724    11.785117    15.665036
# ...

# %%
# data.describe(include='all')

# %%
data.describe()
# Out:
#                   id  median_home_val  median_household_income          ic2  \
# count    3993.000000      3993.000000              3993.000000  3993.000000
# mean    98929.308039      1158.437751               351.622840   400.713248
# std     58179.839090      1033.485773               168.488445   180.568500
# min        12.000000         0.000000                 0.000000     0.000000
# 25%     46153.000000       548.000000               239.000000   284.000000
# 50%    101432.000000       803.000000               318.000000   366.000000
# 75%    151653.000000      1349.000000               425.000000   478.000000
# max    191779.000000      5982.000000              1500.000000  1500.000000
#
#                ic3          ic4            ic5      avggift     target_d
# count  3993.000000  3993.000000    3993.000000  3993.000000  3993.000000
# mean    399.876283   444.732031   16456.413724    11.785117    15.665036
# ...

# %%
summary = data.describe().T

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
summary
# Out:
#                           count          mean           std       min  \
# id                       3993.0  98929.308039  58179.839090  12.00000
# median_home_val          3993.0   1158.437751   1033.485773   0.00000
# median_household_income  3993.0    351.622840    168.488445   0.00000
# ic2                      3993.0    400.713248    180.568500   0.00000
# ic3                      3993.0    399.876283    164.822741   0.00000
# ic4                      3993.0    444.732031    175.004178   0.00000
# ic5                      3993.0  16456.413724   9455.318118   0.00000
# avggift                  3993.0     11.785117     10.172672   2.26087
# target_d                 3993.0     15.665036     12.703041   1.00000
#
#                                 25%       50%            75%       max
# id                       46153.0000  101432.0  151653.000000  191779.0
# median_home_val            548.0000     803.0    1349.000000    5982.0
# ...

# %%
summary['iqr'] = summary['75%']-summary['25%']

# %%
summary
# Out:
#                           count          mean           std       min  \
# id                       3993.0  98929.308039  58179.839090  12.00000
# median_home_val          3993.0   1158.437751   1033.485773   0.00000
# median_household_income  3993.0    351.622840    168.488445   0.00000
# ic2                      3993.0    400.713248    180.568500   0.00000
# ic3                      3993.0    399.876283    164.822741   0.00000
# ic4                      3993.0    444.732031    175.004178   0.00000
# ic5                      3993.0  16456.413724   9455.318118   0.00000
# avggift                  3993.0     11.785117     10.172672   2.26087
# target_d                 3993.0     15.665036     12.703041   1.00000
#
#                                 25%       50%            75%       max  \
# id                       46153.0000  101432.0  151653.000000  191779.0
# median_home_val            548.0000     803.0    1349.000000    5982.0
# ...

# %%
summary['mean'] = list(map(lambda x: round(x,2), summary['mean']))

# %%
summary
# Out:
#                           count      mean           std       min         25%  \
# id                       3993.0  98929.31  58179.839090  12.00000  46153.0000
# median_home_val          3993.0   1158.44   1033.485773   0.00000    548.0000
# median_household_income  3993.0    351.62    168.488445   0.00000    239.0000
# ic2                      3993.0    400.71    180.568500   0.00000    284.0000
# ic3                      3993.0    399.88    164.822741   0.00000    287.0000
# ic4                      3993.0    444.73    175.004178   0.00000    325.0000
# ic5                      3993.0  16456.41   9455.318118   0.00000  11136.0000
# avggift                  3993.0     11.79     10.172672   2.26087      7.1875
# target_d                 3993.0     15.67     12.703041   1.00000     10.0000
#
#                               50%            75%       max            iqr
# id                       101432.0  151653.000000  191779.0  105500.000000
# ...

# %% [markdown]
# # Lesson 2

# %%
# Exploratory data analysis using matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.scatter(x=data['ic2'], y=data['ic3'])
plt.show()

# %%
# Histograms: indicates the frequency of specified ranges of continuous/discrete data

# %%
data['median_home_val'].hist()
plt.show()

# %%
data['median_home_val'].hist(bins=50)
plt.show()

# %%
sns.distplot(data['median_home_val'], bins=20)
plt.show()

# %%
data[['median_home_val']].boxplot()
plt.show()

# %%
sns.boxplot(x="median_home_val", data=data)
plt.show()

# %%
sns.boxplot(y="median_home_val", data=data)
plt.show()

# %%
sns.boxplot(x = 'gender',y='median_home_val', data=data)
plt.show()

# %% [markdown]
# ###### hue : the hue parameter determines which column in the data frame should be used for colour encoding

# %% [markdown]
# - Activity 1 & 2:
# - 1. https://github.com/ironhack-edu/data_1.05_activities/blob/master/1.05_activity_1.md
# - 2. https://github.com/ironhack-edu/data_1.05_activities/blob/master/1.05_activity_2.md
